# %%
# %%bash
# kubectl get pods -n rl --show-all
# Out:
# NAME                                           READY     STATUS    RESTARTS   AGE
# loglocal-kuka-a5b5e773-master-hcdb-0-dqc7c     1/1       Running   0          3m
# ml2k-ue120-kuka-0e6d8e00-master-oecq-0-gjksk   1/1       Running   0          2m
# ml2k-ue30-kuka-0cec3037-master-b8x5-0-d6qrc    1/1       Running   0          2m
# ml2k-ue60-kuka-80b7717b-master-du9x-0-9xsrd    1/1       Running   0          2m

# %%
# %%bash
# kubectl logs ml2k-ue60-kuka-80b7717b-master-du9x-0-9xsrd -n rl
# Out:
# INFO:tensorflow:Tensorflow version: 1.4.1
# INFO:tensorflow:Tensorflow git version: v1.4.0-19-ga52c8d9
# INFO:tensorflow:Start a new run and write summaries and checkpoints to /tmp/test.
# 2018-01-18 22:37:12.750625: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# E0118 22:37:12.753648187       1 ev_epoll1_linux.c:1051]     grpc epoll fd: 3
# 2018-01-18 22:37:12.763828: I tensorflow/core/distributed_runtime/rpc/grpc_channel.cc:215] Initialize GrpcChannelCache for job master -> {0 -> localhost:2222}
# 2018-01-18 22:37:12.766213: I tensorflow/core/distributed_runtime/rpc/grpc_server_lib.cc:324] Started server with target: grpc://localhost:2222
# ...
